# %%
from cryptography.fernet import Fernet

# Gerar chave de criptografia (fazer apenas uma vez)
key = Fernet.generate_key()
with open("fernet_key.key", "wb") as key_file:
    key_file.write(key)
cipher = Fernet(key)

# %%
import os
from cryptography.fernet import Fernet

# Gerar e salvar a chave (faça isso uma vez)
key = Fernet.generate_key()
with open("fernet_key.key", "wb") as key_file:
    key_file.write(key)
cipher = Fernet(key)

# Função para criptografar imagens e salvar com a mesma estrutura
def encrypt_images_to_new_directory(src_root, dst_root):
    for folder, _, files in os.walk(src_root):
        for file in files:
            if file.lower().endswith((".jpg", ".jpeg", ".png")):
                src_path = os.path.join(folder, file)

                # Caminho relativo a partir do diretório raiz
                rel_path = os.path.relpath(src_path, src_root)
                enc_path = os.path.join(dst_root, rel_path + ".enc")

                # Cria diretório de destino, se necessário
                os.makedirs(os.path.dirname(enc_path), exist_ok=True)

                # Criptografa a imagem
                with open(src_path, "rb") as f:
                    img_data = f.read()
                encrypted_data = cipher.encrypt(img_data)

                # Salva arquivo criptografado
                with open(enc_path, "wb") as f_enc:
                    f_enc.write(encrypted_data)

                print(f"Criptografado: {src_path} -> {enc_path}")

# Caminhos de origem e destino
encrypt_images_to_new_directory("dataset", "dataset_criptografado")
# Out:
# Criptografado: dataset\train\deficiente\Fe (1).JPG -> dataset_criptografado\train\deficiente\Fe (1).JPG.enc
# Criptografado: dataset\train\deficiente\Fe (10).jpg -> dataset_criptografado\train\deficiente\Fe (10).jpg.enc
# Criptografado: dataset\train\deficiente\Fe (11).jpg -> dataset_criptografado\train\deficiente\Fe (11).jpg.enc
# Criptografado: dataset\train\deficiente\Fe (12).jpg -> dataset_criptografado\train\deficiente\Fe (12).jpg.enc
# Criptografado: dataset\train\deficiente\Fe (13).jpg -> dataset_criptografado\train\deficiente\Fe (13).jpg.enc
# Criptografado: dataset\train\deficiente\Fe (14).jpg -> dataset_criptografado\train\deficiente\Fe (14).jpg.enc
# Criptografado: dataset\train\deficiente\Fe (15).jpg -> dataset_criptografado\train\deficiente\Fe (15).jpg.enc
# Criptografado: dataset\train\deficiente\Fe (16).jpg -> dataset_criptografado\train\deficiente\Fe (16).jpg.enc
# ...

# %%
import os
from cryptography.fernet import Fernet

# Carregar a chave previamente salva
with open("fernet_key.key", "rb") as key_file:
    key = key_file.read()
cipher = Fernet(key)

# Função para descriptografar imagens e salvar com estrutura preservada
def decrypt_images_to_new_directory(src_root, dst_root):
    for folder, _, files in os.walk(src_root):
        for file in files:
            if file.endswith(".enc"):
                enc_path = os.path.join(folder, file)

                # Caminho relativo
                rel_path = os.path.relpath(enc_path, src_root)
                # Remover a extensão .enc
                rel_img_path = os.path.splitext(rel_path)[0]
                # Caminho do destino
                dec_path = os.path.join(dst_root, rel_img_path)

                # Criar pasta de destino
                os.makedirs(os.path.dirname(dec_path), exist_ok=True)

                # Descriptografar
                with open(enc_path, "rb") as f_enc:
                    encrypted_data = f_enc.read()
                decrypted_data = cipher.decrypt(encrypted_data)

                # Salvar imagem recuperada
                with open(dec_path, "wb") as f_dec:
                    f_dec.write(decrypted_data)

                print(f"Descriptografado: {enc_path} -> {dec_path}")

# Caminhos
decrypt_images_to_new_directory("dataset_criptografado", "dataset_descriptografado")
# Out:
# Descriptografado: dataset_criptografado\train\deficiente\Fe (1).JPG.enc -> dataset_descriptografado\train\deficiente\Fe (1).JPG
# Descriptografado: dataset_criptografado\train\deficiente\Fe (10).jpg.enc -> dataset_descriptografado\train\deficiente\Fe (10).jpg
# Descriptografado: dataset_criptografado\train\deficiente\Fe (11).jpg.enc -> dataset_descriptografado\train\deficiente\Fe (11).jpg
# Descriptografado: dataset_criptografado\train\deficiente\Fe (12).jpg.enc -> dataset_descriptografado\train\deficiente\Fe (12).jpg
# Descriptografado: dataset_criptografado\train\deficiente\Fe (13).jpg.enc -> dataset_descriptografado\train\deficiente\Fe (13).jpg
# Descriptografado: dataset_criptografado\train\deficiente\Fe (14).jpg.enc -> dataset_descriptografado\train\deficiente\Fe (14).jpg
# Descriptografado: dataset_criptografado\train\deficiente\Fe (15).jpg.enc -> dataset_descriptografado\train\deficiente\Fe (15).jpg
# ...
