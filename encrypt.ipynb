# %%
import os
import hashlib
from cryptography.fernet import Fernet
from cryptography.hazmat.primitives.asymmetric import rsa, padding
from cryptography.hazmat.primitives import serialization, hashes
from cryptography.hazmat.primitives.asymmetric import utils as asym_utils

# %%
DATASET_DIR = 'dataset'
OUTPUT_DIR = 'encrypted_dataset'

# Geração de chaves RSA
def generate_rsa_keys():
    private_key = rsa.generate_private_key(public_exponent=65537, key_size=2048)
    public_key = private_key.public_key()

    # Salva as chaves em disco
    with open("private_key.pem", "wb") as f:
        f.write(private_key.private_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PrivateFormat.TraditionalOpenSSL,
            encryption_algorithm=serialization.NoEncryption()
        ))

    with open("public_key.pem", "wb") as f:
        f.write(public_key.public_bytes(
            encoding=serialization.Encoding.PEM,
            format=serialization.PublicFormat.SubjectPublicKeyInfo
        ))
    return private_key, public_key


def encrypt_image(img_path, public_key, private_key):
    with open(img_path, "rb") as file:
        image_data = file.read()

    fernet_key = Fernet.generate_key()
    fernet = Fernet(fernet_key)

    encrypted_image = fernet.encrypt(image_data)

    encrypted_key = public_key.encrypt(
        fernet_key,
        padding.OAEP(mgf=padding.MGF1(algorithm=hashes.SHA256()), algorithm=hashes.SHA256(), label=None)
    )

    # 4. Assinar hash da imagem com chave privada
    digest = hashlib.sha256(image_data).digest()
    signature = private_key.sign(
        digest,
        padding.PSS(mgf=padding.MGF1(hashes.SHA256()), salt_length=padding.PSS.MAX_LENGTH),
        hashes.SHA256()
    )

    return encrypted_image, encrypted_key, signature


# Processa todas as imagens do dataset
def encrypt_dataset():
    if not os.path.exists(OUTPUT_DIR):
        os.makedirs(OUTPUT_DIR)

    private_key, public_key = generate_rsa_keys()

    for split in ['train', 'val']:
        for label in ['deficiente', 'normal']:
            input_dir = os.path.join(DATASET_DIR, split, label)
            output_subdir = os.path.join(OUTPUT_DIR, split, label)
            os.makedirs(output_subdir, exist_ok=True)

            for img_name in os.listdir(input_dir):
                img_path = os.path.join(input_dir, img_name)
                enc_img, enc_key, signature = encrypt_image(img_path, public_key, private_key)

                base = os.path.join(output_subdir, img_name)

                with open(base + '.enc', 'wb') as f:
                    f.write(enc_img)

                with open(base + '.key', 'wb') as f:
                    f.write(enc_key)

                with open(base + '.sig', 'wb') as f:
                    f.write(signature)

encrypt_dataset()

# %%
ENCRYPTED_DIR = 'encrypted_dataset'
DECRYPTED_DIR = 'decrypted_dataset'

# Carrega chave privada RSA
def load_private_key(path="private_key.pem"):
    with open(path, "rb") as key_file:
        private_key = serialization.load_pem_private_key(
            key_file.read(),
            password=None
        )
    return private_key

def load_public_key(path="public_key.pem"):
    with open(path, "rb") as key_file:
        public_key = serialization.load_pem_public_key(key_file.read())
    return public_key


# Desencripta uma imagem com chave Fernet recuperada com RSA
def decrypt_image(encrypted_img_path, encrypted_key_path, sig_path, private_key, public_key):
    # 1. Carregar chave Fernet criptografada
    with open(encrypted_key_path, 'rb') as f:
        encrypted_key = f.read()

    # 2. Descriptografar chave Fernet com RSA
    fernet_key = private_key.decrypt(
        encrypted_key,
        padding.OAEP(mgf=padding.MGF1(algorithm=hashes.SHA256()), algorithm=hashes.SHA256(), label=None)
    )

    fernet = Fernet(fernet_key)

    # 3. Descriptografar imagem
    with open(encrypted_img_path, 'rb') as f:
        encrypted_img = f.read()
    decrypted_img = fernet.decrypt(encrypted_img)

    # 4. Verificar assinatura digital
    with open(sig_path, 'rb') as f:
        signature = f.read()

    digest = hashlib.sha256(decrypted_img).digest()

    try:
        public_key.verify(
            signature,
            digest,
            padding.PSS(mgf=padding.MGF1(hashes.SHA256()), salt_length=padding.PSS.MAX_LENGTH),
            hashes.SHA256()
        )
        print(f"[OK] Assinatura válida: {os.path.basename(encrypted_img_path)}")
    except Exception as e:
        print(f"[ERRO] Assinatura inválida: {os.path.basename(encrypted_img_path)}")

    return decrypted_img


# Percorre diretório e descriptografa
def decrypt_dataset():
    private_key = load_private_key()
    public_key = load_public_key()  # Nova função

    for split in ['train', 'val']:
        for label in ['deficiente', 'normal']:
            input_dir = os.path.join(ENCRYPTED_DIR, split, label)
            output_dir = os.path.join(DECRYPTED_DIR, split, label)
            os.makedirs(output_dir, exist_ok=True)

            for file in os.listdir(input_dir):
                if file.endswith('.enc'):
                    name = file[:-4]
                    img_path = os.path.join(input_dir, name + '.enc')
                    key_path = os.path.join(input_dir, name + '.key')
                    sig_path = os.path.join(input_dir, name + '.sig')

                    decrypted_img = decrypt_image(img_path, key_path, sig_path, private_key, public_key)

                    with open(os.path.join(output_dir, name), 'wb') as f:
                        f.write(decrypted_img)


decrypt_dataset()
# Out:
# [OK] Assinatura válida: Fe (1).JPG.enc
# [OK] Assinatura válida: Fe (10).jpg.enc
# [OK] Assinatura válida: Fe (11).jpg.enc
# [OK] Assinatura válida: Fe (12).jpg.enc
# [OK] Assinatura válida: Fe (13).jpg.enc
# [OK] Assinatura válida: Fe (14).jpg.enc
# [OK] Assinatura válida: Fe (15).jpg.enc
# [OK] Assinatura válida: Fe (16).jpg.enc
# [OK] Assinatura válida: Fe (17).jpg.enc
# [OK] Assinatura válida: Fe (18).jpg.enc
# [OK] Assinatura válida: Fe (19).jpg.enc
# [OK] Assinatura válida: Fe (2).JPG.enc
# [OK] Assinatura válida: Fe (20).jpg.enc
# [OK] Assinatura válida: Fe (21).jpg.enc
# [OK] Assinatura válida: Fe (22).jpg.enc
# [OK] Assinatura válida: Fe (23).jpg.enc
# [OK] Assinatura válida: Fe (24).jpg.enc
# [OK] Assinatura válida: Fe (25).jpg.enc
# [OK] Assinatura válida: Fe (26).jpg.enc
# [OK] Assinatura válida: Fe (27).jpg.enc
# [OK] Assinatura válida: Fe (28).jpg.enc
# [OK] Assinatura válida: Fe (29).jpg.enc
# [OK] Assinatura válida: Fe (3).JPG.enc
# [OK] Assinatura válida: Fe (30).jpg.enc
# [OK] Assinatura válida: Fe (31).jpg.enc
# [OK] Assinatura válida: Fe (32).jpg.enc
# [OK] Assinatura válida: Fe (33).jpg.enc
# [OK] Assinatura válida: Fe (34).JPG.enc
# [OK] Assinatura válida: Fe (35).JPG.enc
# [OK] Assinatura válida: Fe (36).JPG.enc
# [OK] Assinatura válida: Fe (37).JPG.enc
# [OK] Assinatura válida: Fe (38).JPG.enc
# [OK] Assinatura válida: Fe (39).JPG.enc
# [OK] Assinatura válida: Fe (4).JPG.enc
# [OK] Assinatura válida: Fe (40).JPG.enc
# [OK] Assinatura válida: Fe (41).JPG.enc
# [OK] Assinatura válida: Fe (42).JPG.enc
# [OK] Assinatura válida: Fe (43).JPG.enc
# [OK] Assinatura válida: Fe (44).JPG.enc
# [OK] Assinatura válida: Fe (45).JPG.enc
# [OK] Assinatura válida: Fe (46).JPG.enc
# [OK] Assinatura válida: Fe (47).JPG.enc
# [OK] Assinatura válida: Fe (48).JPG.enc
# [OK] Assinatura válida: Fe (49).JPG.enc
# [OK] Assinatura válida: Fe (5).JPG.enc
# [OK] Assinatura válida: Fe (50).JPG.enc
# [OK] Assinatura válida: Fe (51).JPG.enc
# [OK] Assinatura válida: Fe (52).JPG.enc
# [OK] Assinatura válida: Fe (6).JPG.enc
# [OK] Assinatura válida: Fe (7).JPG.enc
# [OK] Assinatura válida: Fe (8).JPG.enc
# [OK] Assinatura válida: Fe (9).JPG.enc
# [OK] Assinatura válida: 20250122_161637.jpg.enc
# [OK] Assinatura válida: 20250122_161657.jpg.enc
# [OK] Assinatura válida: 20250122_161725.jpg.enc
# [OK] Assinatura válida: 20250122_161732.jpg.enc
# [OK] Assinatura válida: 20250122_161737.jpg.enc
# [OK] Assinatura válida: 20250122_161742.jpg.enc
# [OK] Assinatura válida: 20250122_161746.jpg.enc
# [OK] Assinatura válida: 20250122_161749.jpg.enc
# [OK] Assinatura válida: 20250122_161754.jpg.enc
# [OK] Assinatura válida: 20250122_161758.jpg.enc
# [OK] Assinatura válida: 20250122_161803.jpg.enc
# [OK] Assinatura válida: 20250122_161807.jpg.enc
# [OK] Assinatura válida: 20250122_161818.jpg.enc
# [OK] Assinatura válida: 20250122_161822.jpg.enc
# [OK] Assinatura válida: 20250122_161825.jpg.enc
# [OK] Assinatura válida: 20250122_161829.jpg.enc
# [OK] Assinatura válida: 20250122_161834.jpg.enc
# [OK] Assinatura válida: 20250122_161837.jpg.enc
# [OK] Assinatura válida: 20250122_161859.jpg.enc
# [OK] Assinatura válida: 20250122_161919.jpg.enc
# [OK] Assinatura válida: 20250122_161923.jpg.enc
# [OK] Assinatura válida: 20250122_161929.jpg.enc
# [OK] Assinatura válida: 20250122_161934.jpg.enc
# [OK] Assinatura válida: 20250122_161937.jpg.enc
# [OK] Assinatura válida: 20250122_161941.jpg.enc
# [OK] Assinatura válida: 20250122_161944.jpg.enc
# [OK] Assinatura válida: 20250122_161951.jpg.enc
# [OK] Assinatura válida: 20250122_161956.jpg.enc
# [OK] Assinatura válida: 20250122_162000.jpg.enc
# [OK] Assinatura válida: 20250122_162003.jpg.enc
# [OK] Assinatura válida: 20250122_162009.jpg.enc
# [OK] Assinatura válida: 20250122_162012.jpg.enc
# [OK] Assinatura válida: 20250122_162025.jpg.enc
# [OK] Assinatura válida: 20250122_162029.jpg.enc
# [OK] Assinatura válida: 20250122_162032.jpg.enc
# [OK] Assinatura válida: 20250122_162035.jpg.enc
# [OK] Assinatura válida: 20250122_162038.jpg.enc
# [OK] Assinatura válida: 20250122_162041.jpg.enc
# [OK] Assinatura válida: 20250122_162045.jpg.enc
# [OK] Assinatura válida: 20250122_162049.jpg.enc
# [OK] Assinatura válida: 20250122_162054.jpg.enc
# [OK] Assinatura válida: 20250122_162057.jpg.enc
# [OK] Assinatura válida: 20250122_162100.jpg.enc
# [OK] Assinatura válida: 20250122_162104.jpg.enc
# [OK] Assinatura válida: 20250122_162117.jpg.enc
# [OK] Assinatura válida: 20250122_162120.jpg.enc
# [OK] Assinatura válida: 20250122_162122.jpg.enc
# [OK] Assinatura válida: 20250122_162125.jpg.enc
# [OK] Assinatura válida: 20250122_162156.jpg.enc
# [OK] Assinatura válida: 20250122_162200.jpg.enc
# [OK] Assinatura válida: 20250122_162205.jpg.enc
# [OK] Assinatura válida: 20250122_162209.jpg.enc
# [OK] Assinatura válida: 20250122_162228.jpg.enc
# [OK] Assinatura válida: 20250122_162235.jpg.enc
# [OK] Assinatura válida: 20250122_162246.jpg.enc
# [OK] Assinatura válida: 20250122_162249.jpg.enc
# [OK] Assinatura válida: 20250122_162302.jpg.enc
# [OK] Assinatura válida: 20250122_162308.jpg.enc
# [OK] Assinatura válida: 20250122_162314.jpg.enc
# [OK] Assinatura válida: 20250122_162317.jpg.enc
# [OK] Assinatura válida: 20250122_162321.jpg.enc
# [OK] Assinatura válida: 20250122_162324.jpg.enc
# [OK] Assinatura válida: 20250128_162959.jpg.enc
# [OK] Assinatura válida: 20250128_163004.jpg.enc
# [OK] Assinatura válida: 20250128_163008.jpg.enc
# [OK] Assinatura válida: 20250128_163013.jpg.enc
# [OK] Assinatura válida: 20250128_163018.jpg.enc
# [OK] Assinatura válida: 20250128_163021.jpg.enc
# [OK] Assinatura válida: 20250128_163026.jpg.enc
# [OK] Assinatura válida: 20250128_163029.jpg.enc
# [OK] Assinatura válida: 20250128_163032.jpg.enc
# [OK] Assinatura válida: 20250128_163035.jpg.enc
# [OK] Assinatura válida: 20250128_163039.jpg.enc
# [OK] Assinatura válida: 20250128_163042.jpg.enc
# [OK] Assinatura válida: 20250128_163045.jpg.enc
# [OK] Assinatura válida: 20250128_163048.jpg.enc
# [OK] Assinatura válida: 20250128_163052.jpg.enc
# [OK] Assinatura válida: 20250128_163056.jpg.enc
# [OK] Assinatura válida: 20250128_163100.jpg.enc
# [OK] Assinatura válida: 20250128_163103.jpg.enc
# [OK] Assinatura válida: 20250128_163107.jpg.enc
# [OK] Assinatura válida: 20250128_163110.jpg.enc
# [OK] Assinatura válida: 20250128_163113.jpg.enc
# [OK] Assinatura válida: 20250128_163117.jpg.enc
# [OK] Assinatura válida: 20250128_163120.jpg.enc
# [OK] Assinatura válida: 20250128_163123.jpg.enc
# [OK] Assinatura válida: 20250128_163135.jpg.enc
# [OK] Assinatura válida: 20250128_163139.jpg.enc
# [OK] Assinatura válida: 20250128_163141.jpg.enc
# [OK] Assinatura válida: 20250128_163144.jpg.enc
# [OK] Assinatura válida: 20250128_163148.jpg.enc
# [OK] Assinatura válida: 20250128_163151.jpg.enc
# [OK] Assinatura válida: 20250128_163154.jpg.enc
# [OK] Assinatura válida: 20250128_163202.jpg.enc
# [OK] Assinatura válida: 20250128_163206.jpg.enc
# [OK] Assinatura válida: 20250128_163209.jpg.enc
# [OK] Assinatura válida: 20250128_163216.jpg.enc
# [OK] Assinatura válida: 20250128_163218.jpg.enc
# [OK] Assinatura válida: 20250128_163222.jpg.enc
# [OK] Assinatura válida: 20250128_163225.jpg.enc
# [OK] Assinatura válida: 20250128_163229.jpg.enc
# [OK] Assinatura válida: 20250128_163231.jpg.enc
# [OK] Assinatura válida: 20250128_163236.jpg.enc
# [OK] Assinatura válida: 20250128_163239.jpg.enc
# [OK] Assinatura válida: 20250128_163242.jpg.enc
# [OK] Assinatura válida: 20250128_163244.jpg.enc
# [OK] Assinatura válida: 20250128_163247.jpg.enc
# [OK] Assinatura válida: 20250128_163249.jpg.enc
# [OK] Assinatura válida: 20250128_163252.jpg.enc
# [OK] Assinatura válida: 20250128_163255.jpg.enc
# [OK] Assinatura válida: 20250128_163257.jpg.enc
# [OK] Assinatura válida: 20250128_163259.jpg.enc
# [OK] Assinatura válida: 20250128_163304.jpg.enc
# [OK] Assinatura válida: 20250128_163306.jpg.enc
# [OK] Assinatura válida: 20250128_163309.jpg.enc
# [OK] Assinatura válida: 20250128_163312.jpg.enc
# [OK] Assinatura válida: 20250128_163315.jpg.enc
# [OK] Assinatura válida: 20250128_163318.jpg.enc
# [OK] Assinatura válida: 20250128_163321.jpg.enc
# [OK] Assinatura válida: 20250128_163324.jpg.enc
# [OK] Assinatura válida: 20250128_163330.jpg.enc
# [OK] Assinatura válida: 20250128_163333.jpg.enc
# [OK] Assinatura válida: 20250128_163340.jpg.enc
# [OK] Assinatura válida: 20250128_163343.jpg.enc
# [OK] Assinatura válida: 20250128_163347.jpg.enc
# [OK] Assinatura válida: 20250128_163354.jpg.enc
# [OK] Assinatura válida: 20250128_163357.jpg.enc
# [OK] Assinatura válida: 20250128_163359.jpg.enc
# [OK] Assinatura válida: 20250128_163402.jpg.enc
# [OK] Assinatura válida: 20250128_163404.jpg.enc
# [OK] Assinatura válida: 20250128_163407.jpg.enc
# [OK] Assinatura válida: 20250128_163408.jpg.enc
# [OK] Assinatura válida: 20250128_163648.jpg.enc
# [OK] Assinatura válida: 20250128_163652.jpg.enc
# [OK] Assinatura válida: 20250128_163703.jpg.enc
# [OK] Assinatura válida: 20250128_163706.jpg.enc
# [OK] Assinatura válida: 20250128_163716.jpg.enc
# [OK] Assinatura válida: 20250128_163719.jpg.enc
# [OK] Assinatura válida: 20250128_163723.jpg.enc
# [OK] Assinatura válida: 20250128_163726.jpg.enc
# [OK] Assinatura válida: 20250128_163732.jpg.enc
# [OK] Assinatura válida: 20250128_163735.jpg.enc
# [OK] Assinatura válida: 20250128_163751.jpg.enc
# [OK] Assinatura válida: 20250128_163756.jpg.enc
# [OK] Assinatura válida: 20250128_163807.jpg.enc
# [OK] Assinatura válida: 20250128_163810.jpg.enc
# [OK] Assinatura válida: 20250128_163815.jpg.enc
# [OK] Assinatura válida: 20250128_163818.jpg.enc
# [OK] Assinatura válida: 20250128_163822.jpg.enc
# [OK] Assinatura válida: 20250128_163826.jpg.enc
# [OK] Assinatura válida: 20250128_163830.jpg.enc
# [OK] Assinatura válida: 20250128_163833.jpg.enc
# [OK] Assinatura válida: 20250128_163838.jpg.enc
# [OK] Assinatura válida: 20250128_163841.jpg.enc
# [OK] Assinatura válida: 20250128_163844.jpg.enc
# [OK] Assinatura válida: 20250128_163848.jpg.enc
# [OK] Assinatura válida: 20250128_163851.jpg.enc
# [OK] Assinatura válida: 20250128_163854.jpg.enc
# [OK] Assinatura válida: 20250128_163857.jpg.enc
# [OK] Assinatura válida: 20250128_163900.jpg.enc
# [OK] Assinatura válida: 20250128_163902.jpg.enc
# [OK] Assinatura válida: 20250128_163905.jpg.enc
# [OK] Assinatura válida: 20250128_163908.jpg.enc
# [OK] Assinatura válida: 20250128_163912.jpg.enc
# [OK] Assinatura válida: 20250128_163918.jpg.enc
# [OK] Assinatura válida: 20250128_163921.jpg.enc
# [OK] Assinatura válida: 20250128_163924.jpg.enc
# [OK] Assinatura válida: 20250128_163926.jpg.enc
# [OK] Assinatura válida: 20250128_163931.jpg.enc
# [OK] Assinatura válida: 20250128_163934.jpg.enc
# [OK] Assinatura válida: 20250128_163938.jpg.enc
# [OK] Assinatura válida: 20250128_163941.jpg.enc
# [OK] Assinatura válida: 20250128_163947.jpg.enc
# [OK] Assinatura válida: 20250128_163950.jpg.enc
# [OK] Assinatura válida: 20250128_163953.jpg.enc
# [OK] Assinatura válida: 20250128_163956.jpg.enc
# [OK] Assinatura válida: 20250128_163959.jpg.enc
# [OK] Assinatura válida: 20250128_164002.jpg.enc
# [OK] Assinatura válida: 20250128_164004.jpg.enc
# [OK] Assinatura válida: 20250128_164007.jpg.enc
# [OK] Assinatura válida: 20250128_164011.jpg.enc
# [OK] Assinatura válida: 20250128_164014.jpg.enc
# [OK] Assinatura válida: 20250128_164017.jpg.enc
# [OK] Assinatura válida: 20250128_164020.jpg.enc
# [OK] Assinatura válida: 20250128_164023.jpg.enc
# [OK] Assinatura válida: 20250128_164026.jpg.enc
# [OK] Assinatura válida: 20250128_164029.jpg.enc
# [OK] Assinatura válida: 20250128_164032.jpg.enc
# [OK] Assinatura válida: 20250128_164034.jpg.enc
# [OK] Assinatura válida: 20250128_164037.jpg.enc
# [OK] Assinatura válida: 20250128_164043.jpg.enc
# [OK] Assinatura válida: 20250128_164045.jpg.enc
# [OK] Assinatura válida: 20250128_164050.jpg.enc
# [OK] Assinatura válida: 20250128_164052.jpg.enc
# [OK] Assinatura válida: 20250128_164056.jpg.enc
# [OK] Assinatura válida: 20250128_164059.jpg.enc
# [OK] Assinatura válida: 20250128_164419.jpg.enc
# [OK] Assinatura válida: 20250128_164421.jpg.enc
# [OK] Assinatura válida: 20250128_164424.jpg.enc
# [OK] Assinatura válida: 20250128_164425.jpg.enc
# [OK] Assinatura válida: 20250128_164446.jpg.enc
# [OK] Assinatura válida: 20250128_164448.jpg.enc
# [OK] Assinatura válida: 20250128_164451.jpg.enc
# [OK] Assinatura válida: 20250128_164453.jpg.enc
# [OK] Assinatura válida: 20250128_164455.jpg.enc
# [OK] Assinatura válida: 20250128_164457.jpg.enc
# [OK] Assinatura válida: 20250128_164458.jpg.enc
# [OK] Assinatura válida: 20250128_164501.jpg.enc
# [OK] Assinatura válida: 20250128_164503.jpg.enc
# [OK] Assinatura válida: 20250128_164505.jpg.enc
# [OK] Assinatura válida: 20250128_164509.jpg.enc
# [OK] Assinatura válida: 20250128_164512.jpg.enc
# [OK] Assinatura válida: 20250128_164523.jpg.enc
# [OK] Assinatura válida: 20250128_164525.jpg.enc
# [OK] Assinatura válida: 20250128_164528.jpg.enc
# [OK] Assinatura válida: 20250128_164531.jpg.enc
# [OK] Assinatura válida: 20250128_164533.jpg.enc
# [OK] Assinatura válida: 20250128_164536.jpg.enc
# [OK] Assinatura válida: 20250128_164539.jpg.enc
# [OK] Assinatura válida: 20250128_164541.jpg.enc
# [OK] Assinatura válida: 20250128_164544.jpg.enc
# [OK] Assinatura válida: 20250128_164547.jpg.enc
# [OK] Assinatura válida: 20250128_164551.jpg.enc
# [OK] Assinatura válida: 20250128_164553.jpg.enc
# [OK] Assinatura válida: 20250128_164557.jpg.enc
# [OK] Assinatura válida: 20250128_164559.jpg.enc
# [OK] Assinatura válida: 20250128_164602.jpg.enc
# [OK] Assinatura válida: 20250128_164605.jpg.enc
# [OK] Assinatura válida: 20250128_164608.jpg.enc
# [OK] Assinatura válida: 20250128_164611.jpg.enc
# [OK] Assinatura válida: 20250128_164614.jpg.enc
# [OK] Assinatura válida: 20250128_164617.jpg.enc
# [OK] Assinatura válida: 20250128_164620.jpg.enc
# [OK] Assinatura válida: 20250128_164623.jpg.enc
# [OK] Assinatura válida: 20250128_164625.jpg.enc
# [OK] Assinatura válida: 20250128_164628.jpg.enc
# [OK] Assinatura válida: 20250128_164645.jpg.enc
# [OK] Assinatura válida: 20250128_164648.jpg.enc
# [OK] Assinatura válida: 20250128_164654.jpg.enc
# [OK] Assinatura válida: 20250128_164657.jpg.enc
# [OK] Assinatura válida: 20250128_164701.jpg.enc
# [OK] Assinatura válida: 20250128_164704.jpg.enc
# [OK] Assinatura válida: 20250128_164707.jpg.enc
# [OK] Assinatura válida: 20250128_164710.jpg.enc
# [OK] Assinatura válida: 20250128_164713.jpg.enc
# [OK] Assinatura válida: 20250128_164715.jpg.enc
# [OK] Assinatura válida: 20250128_164718.jpg.enc
# [OK] Assinatura válida: 20250128_164720.jpg.enc
# [OK] Assinatura válida: 20250128_164723.jpg.enc
# [OK] Assinatura válida: 20250128_164725.jpg.enc
# [OK] Assinatura válida: 20250128_164729.jpg.enc
# [OK] Assinatura válida: 20250128_164731.jpg.enc
# [OK] Assinatura válida: 20250128_164733.jpg.enc
# [OK] Assinatura válida: 20250128_164735.jpg.enc
# [OK] Assinatura válida: 20250128_164739.jpg.enc
# [OK] Assinatura válida: 20250128_164742.jpg.enc
# [OK] Assinatura válida: 20250128_165019.jpg.enc
# [OK] Assinatura válida: 20250128_165021.jpg.enc
# [OK] Assinatura válida: Fe (53).JPG.enc
# [OK] Assinatura válida: Fe (54).JPG.enc
# [OK] Assinatura válida: Fe (55).JPG.enc
# [OK] Assinatura válida: Fe (56).jpg.enc
# [OK] Assinatura válida: Fe (57).JPG.enc
# [OK] Assinatura válida: Fe (58).JPG.enc
# [OK] Assinatura válida: Fe (59).JPG.enc
# [OK] Assinatura válida: Fe (60).JPG.enc
# [OK] Assinatura válida: Fe (61).JPG.enc
# [OK] Assinatura válida: Fe (62).JPG.enc
# [OK] Assinatura válida: Fe (63).JPG.enc
# [OK] Assinatura válida: Fe (64).JPG.enc
# [OK] Assinatura válida: Fe (65).JPG.enc
# [OK] Assinatura válida: 20250128_165024.jpg.enc
# [OK] Assinatura válida: 20250128_165027.jpg.enc
# [OK] Assinatura válida: 20250128_165029.jpg.enc
# [OK] Assinatura válida: 20250128_165031.jpg.enc
# [OK] Assinatura válida: 20250128_165033.jpg.enc
# [OK] Assinatura válida: 20250128_165035.jpg.enc
# [OK] Assinatura válida: 20250128_165037.jpg.enc
# [OK] Assinatura válida: 20250128_165039.jpg.enc
# [OK] Assinatura válida: 20250128_165042.jpg.enc
# [OK] Assinatura válida: 20250128_165045.jpg.enc
# [OK] Assinatura válida: 20250128_165049.jpg.enc
# [OK] Assinatura válida: 20250128_165051.jpg.enc
# [OK] Assinatura válida: 20250128_165054.jpg.enc
# [OK] Assinatura válida: 20250128_165057.jpg.enc
# [OK] Assinatura válida: 20250128_165059.jpg.enc
# [OK] Assinatura válida: 20250128_165102.jpg.enc
# [OK] Assinatura válida: 20250128_165105.jpg.enc
# [OK] Assinatura válida: 20250128_165108.jpg.enc
# [OK] Assinatura válida: 20250128_165111.jpg.enc
# [OK] Assinatura válida: 20250128_165114.jpg.enc
# [OK] Assinatura válida: 20250128_165116.jpg.enc
# [OK] Assinatura válida: 20250128_165118.jpg.enc
# [OK] Assinatura válida: 20250128_165121.jpg.enc
# [OK] Assinatura válida: 20250128_165124.jpg.enc
# [OK] Assinatura válida: 20250128_165126.jpg.enc
# [OK] Assinatura válida: 20250128_165129.jpg.enc
# [OK] Assinatura válida: 20250128_165131.jpg.enc
# [OK] Assinatura válida: 20250128_165132.jpg.enc
# [OK] Assinatura válida: 20250128_165136.jpg.enc
# [OK] Assinatura válida: 20250128_165138.jpg.enc
# [OK] Assinatura válida: 20250128_165141.jpg.enc
# [OK] Assinatura válida: 20250128_165143.jpg.enc
# [OK] Assinatura válida: 20250128_165146.jpg.enc
# [OK] Assinatura válida: 20250128_165148.jpg.enc
# [OK] Assinatura válida: 20250128_165151.jpg.enc
# [OK] Assinatura válida: 20250128_165153.jpg.enc
# [OK] Assinatura válida: 20250128_165156.jpg.enc
# [OK] Assinatura válida: 20250128_165158.jpg.enc
# [OK] Assinatura válida: 20250128_165201.jpg.enc
# [OK] Assinatura válida: 20250128_165203.jpg.enc
# [OK] Assinatura válida: 20250128_165214.jpg.enc
# [OK] Assinatura válida: 20250128_165216.jpg.enc
# [OK] Assinatura válida: 20250128_165220.jpg.enc
# [OK] Assinatura válida: 20250128_165223.jpg.enc
# [OK] Assinatura válida: 20250128_165227.jpg.enc
# [OK] Assinatura válida: 20250128_165229.jpg.enc
# [OK] Assinatura válida: 20250128_165232.jpg.enc
# [OK] Assinatura válida: 20250128_165234.jpg.enc
# [OK] Assinatura válida: 20250128_165237.jpg.enc
# [OK] Assinatura válida: 20250128_165239.jpg.enc
# [OK] Assinatura válida: 20250128_165242.jpg.enc
# [OK] Assinatura válida: 20250128_165244.jpg.enc
# [OK] Assinatura válida: 20250128_165247.jpg.enc
# [OK] Assinatura válida: 20250128_165249.jpg.enc
# [OK] Assinatura válida: 20250128_165252.jpg.enc
# [OK] Assinatura válida: 20250128_165254.jpg.enc
# [OK] Assinatura válida: 20250128_165259.jpg.enc
# [OK] Assinatura válida: 20250128_165302.jpg.enc
# [OK] Assinatura válida: 20250128_165304.jpg.enc
# [OK] Assinatura válida: 20250128_165307.jpg.enc
# [OK] Assinatura válida: 20250128_165310.jpg.enc
# [OK] Assinatura válida: 20250128_165312.jpg.enc
# [OK] Assinatura válida: 20250128_165315.jpg.enc
# [OK] Assinatura válida: 20250128_165318.jpg.enc
